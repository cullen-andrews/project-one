# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import pandas as pd

# %%
data_df = pd.read_csv("../Resources/CollegeScorecard_Raw_Data/MERGED2018_19_PP.csv", low_memory=False)
#data_df.head()

data_dictionary_df = pd.read_csv("../Resources/DataDictionary.csv", low_memory=False)
data_dictionary_df.head()
# Out:
#              NAME OF DATA ELEMENT dev-category developer-friendly name  \
# 0         Unit ID for institution         root                      id
# 1  8-digit OPE ID for institution         root                 ope8_id
# 2  6-digit OPE ID for institution         root                 ope6_id
# 3                Institution name       school                    name
# 4                            City       school                    city
#
#   API data type VARIABLE NAME  VALUE LABEL SOURCE  \
# 0       integer        UNITID    NaN   NaN  IPEDS
# 1        string         OPEID    NaN   NaN  IPEDS
# 2        string        OPEID6    NaN   NaN  IPEDS
# 3  autocomplete        INSTNM    NaN   NaN  IPEDS
# 4  autocomplete          CITY    NaN   NaN  IPEDS
#
#                              NOTES  Unnamed: 9  Unnamed: 10
# 0  Shown/used on consumer website.         NaN          NaN
# 1  Shown/used on consumer website.         NaN          NaN
# ...

# %%
# state_df = data_df["STABBR"]
# state_df.head()

# %%
# type_df = data_df["SCHTYPE"]
# type_df

# %%
null_cols = data_df.columns[data_df.isnull().all()]
data_df.drop(null_cols, axis = 1, inplace = True)

# %%
data_df.head()
# Out:
#    UNITID    OPEID  OPEID6                               INSTNM        CITY  \
# 0  100654   100200    1002             Alabama A & M University      Normal
# 1  100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 2  100690  2503400   25034                   Amridge University  Montgomery
# 3  100706   105500    1055  University of Alabama in Huntsville  Huntsville
# 4  100724   100500    1005             Alabama State University  Montgomery
#
#   STABBR         ZIP                                       ACCREDAGENCY  \
# 0     AL       35762  Southern Association of Colleges and Schools C...
# 1     AL  35294-0110  Southern Association of Colleges and Schools C...
# 2     AL  36117-3553  Southern Association of Colleges and Schools C...
# 3     AL       35899  Southern Association of Colleges and Schools C...
# 4     AL  36104-0271  Southern Association of Colleges and Schools C...
#
#                      INSTURL  \
# 0              www.aamu.edu/
# ...

# %%
pd.set_option('display.max_rows', None)

data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6806 entries, 0 to 6805
# Columns: 624 entries, UNITID to SCUGFFN_POOLED
# dtypes: float64(540), int64(14), object(70)
# memory usage: 32.4+ MB

# %%
col = pd.Series(data_df.columns)

print(col.head)
# Out:
# <bound method NDFrame.head of 0                                UNITID
# 1                                 OPEID
# 2                                OPEID6
# 3                                INSTNM
# 4                                  CITY
# 5                                STABBR
# 6                                   ZIP
# 7                          ACCREDAGENCY
# 8                               INSTURL
# 9                                NPCURL
# 10                                 HCM2
# 11                                 MAIN
# 12                            NUMBRANCH
# 13                              PREDDEG
# 14                              HIGHDEG
# 15                              CONTROL
# 16                              ST_FIPS
# 17                               REGION
# 18                               LOCALE
# 19                             LATITUDE
# 20                            LONGITUDE
# 21                              CCBASIC
# 22                             CCUGPROF
# ...

# %%
col_list = col.tolist()
col_list
# Out:
# ['UNITID',
#  'OPEID',
#  'OPEID6',
#  'INSTNM',
#  'CITY',
#  'STABBR',
#  'ZIP',
#  'ACCREDAGENCY',
#  'INSTURL',
#  'NPCURL',
#  'HCM2',
#  'MAIN',
#  'NUMBRANCH',
#  'PREDDEG',
#  'HIGHDEG',
#  'CONTROL',
#  'ST_FIPS',
#  'REGION',
#  'LOCALE',
#  'LATITUDE',
#  'LONGITUDE',
#  'CCBASIC',
#  'CCUGPROF',
#  'CCSIZSET',
#  'HBCU',
#  'PBI',
#  'ANNHI',
#  'TRIBAL',
#  'AANAPII',
#  'HSI',
#  'NANTI',
#  'MENONLY',
#  'WOMENONLY',
#  'RELAFFIL',
#  'ADM_RATE',
#  'ADM_RATE_ALL',
#  'SATVR25',
#  'SATVR75',
#  'SATMT25',
#  'SATMT75',
#  'SATVRMID',
#  'SATMTMID',
#  'ACTCM25',
#  'ACTCM75',
#  'ACTEN25',
#  'ACTEN75',
#  'ACTMT25',
#  'ACTMT75',
#  'ACTCMMID',
#  'ACTENMID',
#  'ACTMTMID',
#  'SAT_AVG',
#  'SAT_AVG_ALL',
#  'PCIP01',
#  'PCIP03',
#  'PCIP04',
#  'PCIP05',
#  'PCIP09',
#  'PCIP10',
#  'PCIP11',
#  'PCIP12',
#  'PCIP13',
#  'PCIP14',
#  'PCIP15',
#  'PCIP16',
#  'PCIP19',
#  'PCIP22',
#  'PCIP23',
#  'PCIP24',
#  'PCIP25',
#  'PCIP26',
#  'PCIP27',
#  'PCIP29',
# ...

# %%
dictionary_short_df = col.to_frame

dictionary_short_df
# Out:
# <bound method Series.to_frame of 0                                UNITID
# 1                                 OPEID
# 2                                OPEID6
# 3                                INSTNM
# 4                                  CITY
# 5                                STABBR
# 6                                   ZIP
# 7                          ACCREDAGENCY
# 8                               INSTURL
# 9                                NPCURL
# 10                                 HCM2
# 11                                 MAIN
# 12                            NUMBRANCH
# 13                              PREDDEG
# 14                              HIGHDEG
# 15                              CONTROL
# 16                              ST_FIPS
# 17                               REGION
# 18                               LOCALE
# 19                             LATITUDE
# 20                            LONGITUDE
# 21                              CCBASIC
# 22                             CCUGPROF
# ...

# %%
var_dict = {}
var_data = []


for var in col_list:
    var_data_df = data_dictionary_df.loc[data_dictionary_df["VARIABLE NAME"] == var, : ]
    var_data = var_data_df.values.tolist()
    var_dict.update({var: var_data})
    
    #print(var_data)

#print(var_dict)
    
data_dictionary_short = pd.DataFrame(var_dict)

# data_dictionary_short.head(5)
#print(var_dict)
#     var_data = data_dictionary_df.loc[data_dictionary_df["VARIABLE NAME"] == var, : ]
#     dictionary_short_df[var] = data_dictionary_df.loc[data_dictionary_df["VARIABLE NAME"] == var, : ]
    #print(var_data)

# %%
print(var_dict)
# Out:
# {'UNITID': [['Unit ID for institution', 'root', 'id', 'integer', 'UNITID', nan, nan, 'IPEDS', 'Shown/used on consumer website.', nan, nan]], 'OPEID': [['8-digit OPE ID for institution', 'root', 'ope8_id', 'string', 'OPEID', nan, nan, 'IPEDS', 'Shown/used on consumer website.', nan, nan]], 'OPEID6': [['6-digit OPE ID for institution', 'root', 'ope6_id', 'string', 'OPEID6', nan, nan, 'IPEDS', 'Shown/used on consumer website.', nan, nan]], 'INSTNM': [['Institution name', 'school', 'name', 'autocomplete', 'INSTNM', nan, nan, 'IPEDS', 'Shown/used on consumer website.', nan, nan]], 'CITY': [['City', 'school', 'city', 'autocomplete', 'CITY', nan, nan, 'IPEDS', 'Shown/used on consumer website.', nan, nan]], 'STABBR': [['State postcode', 'school', 'state', 'string', 'STABBR', nan, nan, 'IPEDS', 'Shown/used on consumer website.', nan, nan]], 'ZIP': [['ZIP code', 'school', 'zip', 'string', 'ZIP', nan, nan, 'IPEDS', nan, nan, nan]], 'ACCREDAGENCY': [['Accreditor for institution', 'school', 'accr
# ...
