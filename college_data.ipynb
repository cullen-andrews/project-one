# %%
# %matplotlib notebook

# %%
import os
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_2018 = "Resources/clean2018.csv"
data_2018_df = pd.read_csv(data_2018)
data_2018_df.head()
# Out:
#    Unnamed: 0  UNITID    OPEID  OPEID6                               INSTNM  \
# 0           0  100654   100200    1002             Alabama A & M University
# 1           1  100663   105200    1052  University of Alabama at Birmingham
# 2           2  100690  2503400   25034                   Amridge University
# 3           3  100706   105500    1055  University of Alabama in Huntsville
# 4           4  100724   100500    1005             Alabama State University
#
#          CITY STABBR         ZIP  MAIN  NUMBRANCH  ...  MTHCMP2  MTHCMP3  \
# 0      Normal     AL       35762     1          1  ...      NaN      NaN
# 1  Birmingham     AL  35294-0110     1          1  ...      NaN      NaN
# 2  Montgomery     AL  36117-3553     1          1  ...      NaN      NaN
# 3  Huntsville     AL       35899     1          1  ...      NaN      NaN
# 4  Montgomery     AL  36104-0271     1          1  ...      NaN      NaN
#
# ...

# %%
#UGDS_AIAN
csc_2018_df = data_2018_df.loc[:, ["STABBR","UGDS_WHITE", "UGDS_BLACK", "UGDS_ASIAN", "UGDS_HISP"]] 
csc_2018_df.head()
# Out:
#   STABBR  UGDS_WHITE  UGDS_BLACK  UGDS_ASIAN  UGDS_HISP
# 0     AL      0.0186      0.9120      0.0018     0.0088
# 1     AL      0.5717      0.2553      0.0633     0.0334
# 2     AL      0.2393      0.7151      0.0057     0.0171
# 3     AL      0.7167      0.0969      0.0381     0.0528
# 4     AL      0.0167      0.9352      0.0041     0.0095

# %%
average_race_2018 = csc_2018_df.mean(axis=0)
print(average_race_2018)
# Out:
# UGDS_WHITE    0.491790
# UGDS_BLACK    0.179735
# UGDS_ASIAN    0.037811
# UGDS_HISP     0.181379
# dtype: float64

# %%
data_2014 = "Resources/clean2014.csv"
data_2014_df = pd.read_csv(data_2014)
data_2014_df.head()
# Out:
#    Unnamed: 0  UNITID    OPEID  OPEID6                               INSTNM  \
# 0           0  100654   100200    1002             Alabama A & M University
# 1           1  100663   105200    1052  University of Alabama at Birmingham
# 2           2  100690  2503400   25034                   Amridge University
# 3           3  100706   105500    1055  University of Alabama in Huntsville
# 4           4  100724   100500    1005             Alabama State University
#
#          CITY STABBR         ZIP  MAIN  NUMBRANCH  ...  MTHCMP2  MTHCMP3  \
# 0      Normal     AL       35762     1          1  ...      NaN      NaN
# 1  Birmingham     AL  35294-0110     1          1  ...      NaN      NaN
# 2  Montgomery     AL  36117-3553     1          1  ...      NaN      NaN
# 3  Huntsville     AL       35899     1          1  ...      NaN      NaN
# 4  Montgomery     AL  36104-0271     1          1  ...      NaN      NaN
#
# ...

# %%
#"UGDS_AIAN"
csc_2014_df = data_2014_df.loc[:, ["STABBR", "UGDS_WHITE", "UGDS_BLACK", "UGDS_ASIAN", "UGDS_HISP"]]
csc_2014_df.head()
# Out:
#   STABBR  UGDS_WHITE  UGDS_BLACK  UGDS_ASIAN  UGDS_HISP
# 0     AL      0.0333      0.9353      0.0019     0.0055
# 1     AL      0.5922      0.2600      0.0518     0.0283
# 2     AL      0.2990      0.4192      0.0034     0.0069
# 3     AL      0.6988      0.1255      0.0376     0.0382
# 4     AL      0.0158      0.9208      0.0019     0.0121

# %%
average_race_2014 = csc_2014_df.mean(axis=0)
print(average_race_2014)
# Out:
# UGDS_WHITE    0.510478
# UGDS_BLACK    0.189352
# UGDS_ASIAN    0.033793
# UGDS_HISP     0.161901
# dtype: float64

# %%
data_2011 = "Resources/clean2011.csv"
data_2011_df = pd.read_csv(data_2011)
data_2011_df.head()
# Out:
#    Unnamed: 0  UNITID    OPEID  OPEID6                               INSTNM  \
# 0           0  100654   100200    1002             Alabama A & M University
# 1           1  100663   105200    1052  University of Alabama at Birmingham
# 2           2  100690  2503400   25034                   Amridge University
# 3           3  100706   105500    1055  University of Alabama in Huntsville
# 4           4  100724   100500    1005             Alabama State University
#
#          CITY STABBR         ZIP  MAIN  NUMBRANCH  ...  MTHCMP2  MTHCMP3  \
# 0      Normal     AL       35762     1          1  ...      NaN      NaN
# 1  Birmingham     AL  35294-0110     1          1  ...      NaN      NaN
# 2  Montgomery     AL  36117-3553     1          1  ...      NaN      NaN
# 3  Huntsville     AL       35899     1          1  ...      NaN      NaN
# 4  Montgomery     AL  36104-0271     1          1  ...      NaN      NaN
#
# ...

# %%
# "UGDS_AIAN"
csc_2011_df = data_2011_df.loc[:, ["STABBR", "UGDS_WHITE", "UGDS_BLACK", "UGDS_ASIAN" , "UGDS_HISP"]]
csc_2011_df.head()
# Out:
#   STABBR  UGDS_WHITE  UGDS_BLACK  UGDS_ASIAN  UGDS_HISP
# 0     AL      0.0263      0.9572      0.0017     0.0039
# 1     AL      0.5960      0.2684      0.0446     0.0220
# 2     AL      0.1806      0.1778      0.0000     0.0250
# 3     AL      0.7117      0.1444      0.0346     0.0276
# 4     AL      0.0106      0.9555      0.0008     0.0070

# %%
average_race_2011 = csc_2011_df.mean(axis=0)
print(average_race_2011)
# Out:
# UGDS_WHITE    0.533018
# UGDS_BLACK    0.186000
# UGDS_ASIAN    0.032096
# UGDS_HISP     0.148826
# dtype: float64

# %%
three_years_race_admits_df = pd.DataFrame({"2011":average_race_2011, "2014":average_race_2014,"2018":average_race_2018})

three_years_race_admits_df
# Out:
#                 2011      2014      2018
# UGDS_WHITE  0.533018  0.510478  0.491790
# UGDS_BLACK  0.186000  0.189352  0.179735
# UGDS_ASIAN  0.032096  0.033793  0.037811
# UGDS_HISP   0.148826  0.161901  0.181379

# %%
renamed_all_df = three_years_race_admits_df.rename(index={"UGDS_WHITE":"White",
                                          "UGDS_BLACK":"Black",
                                          "UGDS_ASIAN":"Asian", 
                                          "UGDS_HISP":"Hispanic or Latino"})
renamed_all_df
# Out:
#                         2011      2014      2018
# White               0.533018  0.510478  0.491790
# Black               0.186000  0.189352  0.179735
# Asian               0.032096  0.033793  0.037811
# Hispanic or Latino  0.148826  0.161901  0.181379

# %%
#to see as percents
# df_style = renamed_all_df.style.format({"2011": "{:.2%}",
#                                          "2014": "{:.2%}",
#                                          "2018": "{:.2%}"
#                                         })
    
# display(df_style)
# Out:
# <style  type="text/css" >
# </style><table id="T_a5778c0a_db3f_11ea_b50a_8cc84bad7d7e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >2011</th>        <th class="col_heading level0 col1" >2014</th>        <th class="col_heading level0 col2" >2018</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a5778c0a_db3f_11ea_b50a_8cc84bad7d7elevel0_row0" class="row_heading level0 row0" >White</th>
#                         <td id="T_a5778c0a_db3f_11ea_b50a_8cc84bad7d7erow0_col0" class="data row0 col0" >53.30%</td>
#                         <td id="T_a5778c0a_db3f_11ea_b50a_8cc84bad7d7erow0_col1" class="data row0 col1" >51.05%</td>
#                         <td id="T_a5778c0a_db3f_11ea_b50a_8cc84bad7d7erow0_col2" class="data row0 col2" >49.18%</td>
#             </tr>
#             <tr>
# ...

# %%
renamed_all_df.plot.bar()

plt.title("Proportion of Students, by Race, Admitted to Colleges in the U.S.")
plt.ylabel("Proportion of Total Admitted Students")
plt.xlabel("Race")

plt.savefig ("images/race_of_admitted_students.png")

plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">
